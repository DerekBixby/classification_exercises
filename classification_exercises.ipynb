# %% [markdown]
# ## Classification

# %% [markdown]
# Part 1

# %% [markdown]
# 4. create df_iris from pydata iris dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from pydataset import data

df_iris = data('iris')
df_iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# a. print the first 3 rows

# %%
print(df_iris.head(3))
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# b. print the number of rows and columns

# %%
print (df_iris.shape)
# Out:
# (150, 5)

# %% [markdown]
# c. print the column names

# %%
print(list(df_iris.columns))
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
# d. print the data type in each column

# %%
print(df_iris.dtypes)
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %% [markdown]
# e. print the summary statistic for each of the numberic variables

# %%
df_iris.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# 5. read data from google sheet into a dataframe called df_google

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_googlesheet = pd.read_csv(csv_export_url)
df_googlesheet.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# a. print first 3 rows

# %%
print(df_googlesheet.head(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# b. print # of rows and columns

# %%
print (df_googlesheet.shape)
# Out:
# (891, 12)

# %% [markdown]
# b. print column names

# %%
print(list(df_googlesheet.columns))
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# c. print data type of each column

# %%
print(df_googlesheet.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# d. print summary statistics for each numeric variable

# %%
df_googlesheet.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
print(df_googlesheet['PassengerId'].describe())
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
print(df_googlesheet['Survived'].describe())
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
print(df_googlesheet['Pclass'].describe())
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
print(df_googlesheet['SibSp'].describe())
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
print(df_googlesheet['Parch'].describe())
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
print(df_googlesheet['Fare'].describe())
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# e. print unique values for each categorical variable

# %%
df_googlesheet.value_counts().T
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
print(df_googlesheet.Name.value_counts())
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
print(df_googlesheet.Sex.value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
print(df_googlesheet.Ticket.value_counts())
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
print(df_googlesheet.Cabin.value_counts())
# Out:
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# C22 C26            3
# F33                3
# F2                 3
# E101               3
# D                  3
# C78                2
# C93                2
# E8                 2
# D36                2
# B77                2
# C123               2
# E121               2
# E44                2
# D35                2
# C125               2
# E67                2
# B35                2
# B18                2
# E24                2
# B49                2
# C65                2
# B20                2
# B5                 2
# B57 B59 B63 B66    2
# C126               2
# B51 B53 B55        2
# F4                 2
# C124               2
# F G73              2
# B58 B60            2
# C52                2
# D33                2
# C68                2
# D20                2
# D26                2
# B28                2
# C83                2
# E25                2
# D17                2
# B22                2
# ...

# %%
print(df_googlesheet.Embarked.value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# 6. Download number 5's file into an Excel. Read the downloaded file into a dataframe named df_excel

# %%
url = "/Users/derekbixby/codeup-data-science/classification_exercises/train.xlsx"

df = pd.read_excel(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# a. assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df.head(100)

df_excel_sample
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# b. print number of rows from original datafram

# %%
df.shape[0]
# Out:
# 891

# %% [markdown]
# c. print first 5 column names

# %%
df_columns = list(df.columns)
df_columns[:5]
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex']

# %% [markdown]
# d. print column names that have a data type of object

# %%
objects = df.select_dtypes('object')
list(objects.columns)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# e. compute the range for each of the numeric variables

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_stats = df[['Age', 'Fare']].describe().T

# %%
titanic_stats['range'] = titanic_stats['max'] - titanic_stats['min']
titanic_stats
# Out:
#       count       mean        std   min      25%      50%   75%       max  \
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292
#
#          range
# Age    79.5800
# Fare  512.3292

# %% [markdown]
# Part 2: make new python module called acquire.py to hold following data acquisition functions

# %% [markdown]
# 7. get_titanic_data

# %%
def new_titanic_data():

    sql_query = 'SELECT * FROM passengers'   

    df = pd.read_sql(sql_query, get_db_url('titanic_db'))   
    return df

def get_titanic_data():

    if os.path.isfile('titanic_df.csv'):
        
        df = pd.read_csv('titanic_df.csv', index_col=0)
        
    else:        

        df = new_titanic_data()
        
        df.to_csv('titanic_df.csv')
        
    return df

# %% [markdown]
# 8. get_iris_data

# %%
def new_iris_data():

    sql_query = """
                SELECT 
                    species_id,
                    species_name,
                    sepal_length,
                    sepal_width,
                    petal_length,
                    petal_width
                FROM measurements
                JOIN species USING(species_id)
                """
    

    df = pd.read_sql(sql_query, get_db_url('iris_db'))
    
    return df

def get_iris_data():

    if os.path.isfile('iris_df.csv'):
        
        df = pd.read_csv('iris_df.csv', index_col=0)
        
    else:       

        df = new_iris_data()
        
        df.to_csv('iris_df.csv')
        
    return df

# %% [markdown]
# 9. get_telco_data

# %%
def new_telco_data():

    sql_query = """
                select * from customers
                join contract_types using (contract_type_id)
                join internet_service_types using (internet_service_type_id)
                join payment_types using (payment_type_id)
                """
    
    df = pd.read_sql(sql_query, get_db_url('telco_churn'))
    
    return df

def get_telco_data():

    if os.path.isfile('telco.csv'):
        

        df = pd.read_csv('telco.csv', index_col=0)    
    else:   

        df = new_telco_data()
        
        df.to_csv('telco.csv')
        
    return df

# %% [markdown]
# 10. added

# %% [markdown]
# ## Data Preparation Exercises

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from pydataset import data

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

from acquire import get_iris_data
from acquire import get_titanic_data
from acquire import get_telco_data

import os
import acquire
from env import get_db_url

# %% [markdown]
# Iris Data

# %% [markdown]
# 1. use acquire.py to load iris data

# %%
from acquire import get_iris_data

df_iris = get_iris_data()
df_iris.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %% [markdown]
# 2. Drop species_id and measurement_id columns

# %%
df_iris = df_iris.drop(columns=['species_id'])
df_iris
# Out:
#     species_name  sepal_length  sepal_width  petal_length  petal_width
# 0         setosa           5.1          3.5           1.4          0.2
# 1         setosa           4.9          3.0           1.4          0.2
# 2         setosa           4.7          3.2           1.3          0.2
# 3         setosa           4.6          3.1           1.5          0.2
# 4         setosa           5.0          3.6           1.4          0.2
# 5         setosa           5.4          3.9           1.7          0.4
# 6         setosa           4.6          3.4           1.4          0.3
# 7         setosa           5.0          3.4           1.5          0.2
# 8         setosa           4.4          2.9           1.4          0.2
# 9         setosa           4.9          3.1           1.5          0.1
# 10        setosa           5.4          3.7           1.5          0.2
# 11        setosa           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# 3. Rename the species_name column to just species

# %%
df_iris = df_iris.rename(columns={'species_name': 'species'})
df_iris
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# 4. Create dummy variables of the species name and concatenate onto the iris dataframe.

# %%
df_dummies = pd.get_dummies(df_iris[['species']])
df_dummies.head()
# Out:
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %%
df_iris = pd.concat([df_iris, df_dummies], axis=1)
df_iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica  species_setosa  \
# 0               1                   0                  0               1
# 1               1                   0                  0               1
# 2               1                   0                  0               1
# 3               1                   0                  0               1
# 4               1                   0                  0               1
#
#    species_versicolor  species_virginica  species_setosa  species_versicolor  \
# ...

# %% [markdown]
# 5. Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def clean_iris(df):

    df = df.drop(columns =['species_id'])
    
    df = df.rename(columns={'species_name': 'species'})

    dummy_df = pd.get_dummies(df[['species']], drop_first=False)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %% [markdown]
# Titanic Dataset

# %% [markdown]
# 1. Use the function defined in acquire.py to load the Titanic data.

# %%
from acquire import get_titanic_data

df_titanic = get_titanic_data()
df_titanic
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns.

# %%
df_titanic = df_titanic.drop(columns=['deck', 'embark_town',])

# %%
df_titanic = df_titanic.drop(columns=['class'])
df_titanic

# %%
df_titanic
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked  alone
# 0          S      0
# 1          C      0
# 2          S      1
# ...

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_df = pd.get_dummies(df_titanic[['sex', 'embarked']], drop_first=True)
dummy_df.head()
# Out:
#    sex_male  embarked_Q  embarked_S
# 0         1           0           1
# 1         0           0           0
# 2         0           0           1
# 3         0           0           1
# 4         1           0           1

# %%
df_titanic = pd.concat([df_titanic, dummy_df], axis=1)

# %% [markdown]
# 4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def clean_titanic(df):

    df = df.drop(columns =['embark_town','class','deck'])

    df.embarked = df.embarked.fillna(value='S')

    dummy_df = pd.get_dummies(df[['sex','embarked']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %% [markdown]
# Telco Dataset

# %% [markdown]
# 1. Use the function defined in acquire.py to load the Telco data.

# %%
from acquire import get_telco_data

df_telco = get_telco_data()
df_telco.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
df_telco = df_telco.drop(columns =['payment_type_id','internet_service_type_id','contract_type_id'])
df_telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# ...

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_df = pd.get_dummies(df_telco[['gender','partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security', 'online_backup', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'contract_type', 'internet_service_type', 'payment_type']], drop_first=True)
dummy_df.head()
# Out:
#    gender_Male  partner_Yes  dependents_Yes  phone_service_Yes  \
# 0            0            1               1                  1
# 1            1            0               0                  1
# 2            1            0               0                  1
# 3            1            1               0                  1
# 4            0            1               0                  1
#
#    multiple_lines_No phone service  multiple_lines_Yes  \
# 0                                0                   0
# 1                                0                   1
# 2                                0                   0
# 3                                0                   0
# 4                                0                   0
#
#    online_security_No internet service  online_security_Yes  \
# 0                                    0                    0
# 1                                    0                    0
# 2                                    0                    0
# ...

# %%
df_telco = pd.concat([df_telco, dummy_df], axis=1)
df_telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   streaming_movies_No internet service streaming_movies_Yes  \
# 0                                    0                    0
# ...

# %% [markdown]
# 4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def clean_telco(df):

    df = df.drop(columns =['payment_type_id','internet_service_type_id','contract_type_id'])

    dummy_df = pd.get_dummies(df[['gender','partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security', 'online_backup', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'contract_type', 'internet_service_type', 'payment_type']], drop_first=True)
    df = pd.concat([df, dummy_df], axis=1)
    return df

# %% [markdown]
# Split Data

# %% [markdown]
# 1. Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from pydataset import data

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

from acquire import get_iris_data
from acquire import get_titanic_data
from acquire import get_telco_data

from prepare import split_data

import os
import acquire
from env import get_db_url

# %%
from sklearn.model_selection import train_test_split

def split_data(df, test_size=.2, validate_size=.25, col_to_stratify=None, random_state=None):
    
    if col_to_stratify == None:
    
        train_validate, test = train_test_split(df, test_size=test_size, random_state=random_state)
        train, validate = train_test_split(train_validate,
                                       test_size=validate_size,
                                       random_state=random_state,)
    else:                                                        
        train_validate, test = train_test_split(df, test_size=test_size, random_state=random_state, stratify=df[col_to_stratify])
        train, validate = train_test_split(train_validate,
                                       test_size=validate_size,
                                       random_state=random_state,
                                       stratify=train_validate[col_to_stratify])
    return train, validate, test

# %% [markdown]
# 2. Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
df = get_iris_data()
df.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
df = clean_iris(df)
df.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %%
train_iris, validate_iris, test_iris = split_data(df, col_to_stratify='species')
train_iris, validate_iris, test_iris
# Out:
# (        species  sepal_length  sepal_width  petal_length  petal_width  \
#  126   virginica           6.2          2.8           4.8          1.8
#  107   virginica           7.3          2.9           6.3          1.8
#  53   versicolor           5.5          2.3           4.0          1.3
#  57   versicolor           4.9          2.4           3.3          1.0
#  42       setosa           4.4          3.2           1.3          0.2
#  77   versicolor           6.7          3.0           5.0          1.7
#  3        setosa           4.6          3.1           1.5          0.2
#  74   versicolor           6.4          2.9           4.3          1.3
#  4        setosa           5.0          3.6           1.4          0.2
#  16       setosa           5.4          3.9           1.3          0.4
#  125   virginica           7.2          3.2           6.0          1.8
#  113   virginica           5.7          2.5           5.0          2.0
# ...

# %% [markdown]
# 3. Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %%
df = get_titanic_data()
df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
df = clean_titanic(df)
df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  alone  sex_male  embarked_Q  embarked_S
# 0        S      0         1           0           1
# 1        C      0         0           0           0
# 2        S      1         0           0           1
# 3        S      0         0           0           1
# 4        S      1         1           0           1

# %%
train_titanic, validate_titanic, test_titanic = split_data(df, col_to_stratify='survived')
train_titanic, validate_titanic, test_titanic
# Out:
# (     passenger_id  survived  pclass     sex   age  sibsp  parch      fare  \
#  873           873         0       3    male  47.0      0      0    9.0000
#  99             99         0       2    male  34.0      1      0   26.0000
#  182           182         0       3    male   9.0      4      2   31.3875
#  334           334         1       1  female   NaN      1      0  133.6500
#  740           740         1       1    male   NaN      0      0   30.0000
#  ..            ...       ...     ...     ...   ...    ...    ...       ...
#  320           320         0       3    male  22.0      0      0    7.2500
#  231           231         0       3    male  29.0      0      0    7.7750
#  180           180         0       3  female   NaN      8      2   69.5500
#  882           882         0       3  female  22.0      0      0   10.5167
#  838           838         1       3    male  32.0      0      0   56.4958
#
#      embarked  alone  sex_male  embarked_Q  embarked_S
# ...

# %% [markdown]
# 4. Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
df = get_telco_data()
df.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
df = clean_telco(df)
df.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   streaming_movies_No internet service streaming_movies_Yes  \
# 0                                    0                    0
# ...

# %%
train_telco, validate_telco, test_telco = split_data(df, col_to_stratify='churn')
train_telco, validate_telco, test_telco
# Out:
# (     customer_id  gender  senior_citizen partner dependents  tenure  \
#  5939  8375-DKEBR  Female               1      No         No       1
#  5691  8017-UVSZU  Female               0     Yes         No      40
#  1625  2364-UFROM    Male               0      No         No      30
#  6268  8871-JLMHM  Female               0     Yes         No      68
#  1474  2180-DXNEG  Female               0      No         No      12
#  ...          ...     ...             ...     ...        ...     ...
#  2898  4129-LYCOI  Female               0      No        Yes      67
#  6601  9385-EHGDO  Female               0     Yes        Yes      35
#  3226  4625-XMOYM  Female               0     Yes        Yes      72
#  6023  8514-VZHEB    Male               0     Yes        Yes      59
#  468   0684-AOSIH    Male               0     Yes         No       1
#
#       phone_service multiple_lines      online_security        online_backup  \
# ...

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# Part 1 Section 1 - iris_db: Using iris data from our mySQL server and the methods used in the lesson above:

# %% [markdown]
# 1. Acquire, prepare & split your data.

# %%
iris_df = get_iris_data()
iris_df.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
iris_df = clean_iris(iris_df)
iris_df.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %%
iris_df.shape
# Out:
# (150, 8)

# %%
train_iris, validate_iris, test_iris = split_data(iris_df)
train_iris.shape
# Out:
# (90, 8)

# %% [markdown]
# 2. Univariate Stats

# %% [markdown]
# a. For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
col_cat = [] #categorical variable empty list
col_num = [] #numeric variable empty list

for col in train_iris.columns[:-4]:
    print(col)
    if train_iris[col].dtype == 'O':
        col_cat.append(col)
    else:
        if len(train_iris[col].unique()) < 4: #makes anything with less than 4 unique values into a categorical value
            col_cat.append(col)
        else:
            col_num.append(col)
# Out:
# species
# sepal_length
# sepal_width
# petal_length

# %%
col_num
# Out:
# ['sepal_length', 'sepal_width', 'petal_length']

# %%
for col in col_num:
    print(col.upper())
    print(train_iris[col].value_counts())
    print(train_iris[col].describe())
    print(plt.hist(x=train_iris[col])),
    print(plt.boxplot(x=train_iris[col]))
    
    plt.show()
# Out:
# SEPAL_LENGTH
# 5.8    5
# 5.7    5
# 4.8    5
# 5.1    5
# 6.3    5
# 6.0    5
# 5.0    5
# 4.6    4
# 6.1    4
# 4.9    4
# 5.6    3
# 6.7    3
# 6.4    3
# 5.4    3
# 6.9    3
# 5.2    2
# 5.9    2
# 4.7    2
# 6.8    2
# 6.2    2
# 4.4    2
# 7.7    2
# 5.5    2
# 7.1    1
# 4.5    1
# 5.3    1
# 7.2    1
# 6.5    1
# 7.3    1
# 7.6    1
# 7.4    1
# 4.3    1
# 7.9    1
# 6.6    1
# 7.0    1
# Name: sepal_length, dtype: int64
# count    90.000000
# mean      5.782222
# std       0.879808
# min       4.300000
# 25%       5.000000
# 50%       5.750000
# 75%       6.300000
# max       7.900000
# Name: sepal_length, dtype: float64
# (array([ 8., 16.,  8., 13., 12., 14.,  7.,  5.,  3.,  4.]), array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]), <BarContainer object of 10 artists>)
# ...

# %% [markdown]
# b. For each species (categorical variable): create a frequency table and a bar plot of those frequencies.

# %%
for col in col_cat:
    print(col.upper())
    print(train_iris[col].value_counts())
    print(train_iris[col].value_counts(normalize=True))
    sns.countplot(x=col, data=train_iris)
    plt.show()
    print()
# Out:
# SPECIES
# versicolor    32
# setosa        31
# virginica     27
# Name: species, dtype: int64
# versicolor    0.355556
# setosa        0.344444
# virginica     0.300000
# Name: species, dtype: float64

# %% [markdown]
# c. Document takeaways & any actions.

# %% [markdown]
#     no obvious issues with data
#     categorical variables are categorical
#     Target variable: species
#     petal length seems to be normally distributed
#     other numeric variables may not be normally distributed
#     sepal length seems skewed to the right
#     petal length seems bimodal
#     Species counts are roughly similar

# %% [markdown]
# 3. Bivariate Stats

# %% [markdown]
# a. Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %%
train_iris.head()
# Out:
#        species  sepal_length  sepal_width  petal_length  petal_width  \
# 82  versicolor           5.8          2.7           3.9          1.2
# 52  versicolor           6.9          3.1           4.9          1.5
# 26      setosa           5.0          3.4           1.6          0.4
# 73  versicolor           6.1          2.8           4.7          1.2
# 83  versicolor           6.0          2.7           5.1          1.6
#
#     species_setosa  species_versicolor  species_virginica
# 82               0                   1                  0
# 52               0                   1                  0
# 26               1                   0                  0
# 73               0                   1                  0
# 83               0                   1                  0

# %%
train_iris.sepal_length.mean()
# Out:
# 5.782222222222222

# %%
graph = sns.barplot(data=train_iris, x='species', y='sepal_length')
graph.axhline(train_iris.sepal_length.mean())
plt.show()

# %%
graph = sns.barplot(data=train_iris, x='species', y='sepal_width')
graph.axhline(train_iris.sepal_width.mean())
plt.show()

# %%
graph = sns.barplot(data=train_iris, x='species', y='petal_length')
graph.axhline(train_iris.petal_length.mean())
plt.show()

# %%
graph = sns.barplot(data=train_iris, x='species', y='petal_width')
graph.axhline(train_iris.petal_width.mean())
plt.show()

# %% [markdown]
# b. For each measurement type, compute the descriptive statistics for each species.

# %%
train_iris.head()
# Out:
#        species  sepal_length  sepal_width  petal_length  petal_width  \
# 82  versicolor           5.8          2.7           3.9          1.2
# 52  versicolor           6.9          3.1           4.9          1.5
# 26      setosa           5.0          3.4           1.6          0.4
# 73  versicolor           6.1          2.8           4.7          1.2
# 83  versicolor           6.0          2.7           5.1          1.6
#
#     species_setosa  species_versicolor  species_virginica
# 82               0                   1                  0
# 52               0                   1                  0
# 26               1                   0                  0
# 73               0                   1                  0
# 83               0                   1                  0

# %%
train_iris_drop = train_iris.drop(columns='species_setosa', 'species_versicolor', 'species_virginica')
train_iris_drop.head()
# Out:
#   Cell In[126], line 1
#     train_iris_drop = train_iris.drop(columns='species_setosa', 'species_versicolor', 'species_virginica')
#                                                                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
train_iris_melt = train_iris.melt(id_vars=train_iris.species,             
              value_name='measure')
train_iris_melt.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 train_iris_melt = train_iris.melt(id_vars=train_iris.species,
#       2               value_name='measure')
#       3 train_iris_melt.head()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:9127, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9116 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9117 def melt(
#    9118     self,
#    (...)
#    9124     ignore_index: bool = True,
#    9125 ) -> DataFrame:
# -> 9127     return melt(
#    9128         self,
#    9129         id_vars=id_vars,
#    9130         value_vars=value_vars,
#    9131         var_name=var_name,
#    9132         value_name=value_name,
#    9133         col_level=col_level,
# ...

# %% [markdown]
# c. For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %%
alpha = .05
    virginica_stat = train_iris [train_iris.species_virginica == 1].sepal_length

    versicolor_stat = train_iris [train_iris.species_versicolor == 1].sepal_length
    t, p = stats.mannwhitneyu(virginica_stat, versicolor_stat)
    t,p
# Out:
# (640.0, 0.0015683621125785346)

# %%
virginica_stat = train_iris [train_iris.species_virginica == 1].sepal_width

versicolor_stat = train_iris [train_iris.species_versicolor == 1].sepal_width
t, p = stats.mannwhitneyu(virginica_stat, versicolor_stat)
t,p
# Out:
# (534.0, 0.12004198723567228)

# %%
virginica_stat = train_iris [train_iris.species_virginica == 1].petal_width

versicolor_stat = train_iris [train_iris.species_versicolor == 1].petal_width
t, p = stats.mannwhitneyu(virginica_stat, versicolor_stat)
t,p
# Out:
# (837.5, 6.165120868475528e-10)

# %%
virginica_stat = train_iris [train_iris.species_virginica == 1].petal_length

versicolor_stat = train_iris [train_iris.species_versicolor == 1].petal_length
t, p = stats.mannwhitneyu(virginica_stat, versicolor_stat)
t,p
# Out:
# (837.0, 7.206911949411852e-10)

# %% [markdown]
# d. Document takeaways & any actions.

# %% [markdown]
# Petal length and width differ widely amongst species and are, therefore, likely good candidates
# for predicting the target variable species
#
# petal length, petal width, and sepal length between virginica and versicolor species have a statistically significant mean difference

# %% [markdown]
# 4.

# %% [markdown]
# a. Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(data=train_iris, hue='species')

# %% [markdown]
# b. Visualize two numeric variables of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(data=train_iris, x="petal_width", y="petal_length", hue="species")
plt.show()

# %% [markdown]
# c. Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
train_iris.shape
# Out:
# (90, 8)

# %%
train_iris_melted = train_iris.melt(id_vars=train_iris.columns[:1],
              value_vars=['petal_length', 'petal_width', 'sepal_length', 'sepal_width'],
              var_name = 'measure_type',          
              value_name='measure')
train_iris_melted.shape
# Out:
# (360, 3)

# %%
train_iris_melted.head()
# Out:
#       species  measure_type  measure
# 0   virginica  petal_length      5.1
# 1   virginica  petal_length      5.6
# 2   virginica  petal_length      6.1
# 3      setosa  petal_length      1.6
# 4  versicolor  petal_length      4.5

# %%
train_iris_melted.groupby(['species', 'measure_type']).describe()
# Out:
#                         measure                                               \
#                           count      mean       std  min    25%   50%    75%
# species    measure_type
# setosa     petal_length    31.0  1.458065  0.191092  1.0  1.350  1.50  1.600
#            petal_width     31.0  0.238710  0.120215  0.1  0.200  0.20  0.250
#            sepal_length    31.0  4.996774  0.346875  4.3  4.800  5.00  5.150
#            sepal_width     31.0  3.422581  0.349962  2.9  3.150  3.40  3.650
# versicolor petal_length    24.0  4.145833  0.464364  3.3  3.875  4.15  4.500
#            petal_width     24.0  1.245833  0.184106  1.0  1.075  1.30  1.325
#            sepal_length    24.0  5.829167  0.518760  4.9  5.500  5.75  6.100
#            sepal_width     24.0  2.670833  0.325014  2.0  2.400  2.75  2.900
# virginica  petal_length    35.0  5.565714  0.524653  4.8  5.100  5.60  5.850
#            petal_width     35.0  2.051429  0.272647  1.5  1.800  2.10  2.300
# ...

# %%
sns.swarmplot(data=train_iris_melted, x='measure_type', y='measure', hue='species')
plt.show()
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# d. Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

# %% [markdown]
# is petal width significantly different between setosa and versicolor? Ho: no, ha: yes

# %%
graph = sns.barplot(data=train_iris, x='species', y='petal_width')
graph.axhline(train_iris.petal_width.mean())
plt.show()

# %%
a = .05
setosa_stat = train_iris [train_iris.species_setosa == 1].petal_width

versicolor_stat = train_iris [train_iris.species_versicolor == 1].petal_width
t, p = stats.mannwhitneyu(setosa_stat, versicolor_stat)
t,p
# Out:
# (0.0, 1.239325099337379e-10)

# %% [markdown]
# e. Document takeaways and any actions.

# %% [markdown]
# we can reject the null hypothesis as there appears to be a statistically significant difference in petal width between sartosa and versicolor species. Therefore, petal width could be a good driver of difference between these species.

# %% [markdown]
# Part 2 titanic dataset

# %%
titanic_df = get_titanic_data()
titanic_df = clean_titanic(titanic_df)

train_titanic, validate_titanic, test_titanic = split_data(titanic_df, col_to_stratify='survived')
train_titanic.shape

# %%
titanic_df = get_titanic_data()
titanic_df.shape
# Out:
# (891, 13)

# %%
titanic_df = clean_titanic(titanic_df)
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  alone  sex_male  embarked_Q  embarked_S
# 0        S      0         1           0           1
# 1        C      0         0           0           0
# 2        S      1         0           0           1
# 3        S      0         0           0           1
# 4        S      1         1           0           1

# %%
train_titanic, validate_titanic, test_titanic = split_data(titanic_df, col_to_stratify='survived')
train_titanic.shape
# Out:
# (534, 13)

# %%
train_titanic.head()
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 310           310         1       1  female  24.0      0      0  83.1583
# 663           663         0       3    male  36.0      0      0   7.4958
# 539           539         1       1  female  22.0      0      2  49.5000
# 456           456         0       1    male  65.0      0      0  26.5500
# 468           468         0       3    male   NaN      0      0   7.7250
#
#     embarked  alone  sex_male  embarked_Q  embarked_S
# 310        C      1         0           0           0
# 663        S      1         1           0           1
# 539        C      0         0           0           0
# 456        S      1         1           0           1
# 468        Q      1         1           1           0

# %% [markdown]
# a. Determine drivers of the target variable

# %%
col_cat = [] #this is for my categorical varibles
col_num = [] #this is for my numeric varibles

for col in train_titanic.columns[:-3]:
    print(col)
    if train_titanic[col].dtype == 'O':
        col_cat.append(col)
    else:
        if len(train_titanic[col].unique()) < 4: #making anything with less than 4 unique values a catergorical value
            col_cat.append(col)
        else:
            col_num.append(col)
# Out:
# passenger_id
# survived
# pclass
# sex
# age
# sibsp
# parch
# fare
# embarked
# alone

# %%
col_cat
# Out:
# ['survived', 'pclass', 'sex', 'embarked', 'alone']

# %%
col_num
# Out:
# ['passenger_id', 'age', 'sibsp', 'parch', 'fare']

# %%
for col in col_cat:
    print(col.upper())
    print(train_titanic[col].value_counts())
    print(train_titanic[col].value_counts(normalize=True))
    sns.countplot(x=col, data=train_titanic)
    plt.show()
    print()
# Out:
# SURVIVED
# 0    329
# 1    205
# Name: survived, dtype: int64
# 0    0.616105
# 1    0.383895
# Name: survived, dtype: float64
# PCLASS
# 3    291
# 2    122
# 1    121
# Name: pclass, dtype: int64
# 3    0.544944
# 2    0.228464
# 1    0.226592
# Name: pclass, dtype: float64
# SEX
# male      343
# female    191
# Name: sex, dtype: int64
# male      0.642322
# female    0.357678
# Name: sex, dtype: float64
# EMBARKED
# S    381
# C    107
# Q     46
# Name: embarked, dtype: int64
# S    0.713483
# C    0.200375
# Q    0.086142
# Name: embarked, dtype: float64
# ALONE
# 1    312
# 0    222
# Name: alone, dtype: int64
# 1    0.58427
# 0    0.41573
# Name: alone, dtype: float64

# %%
for col in col_num:
    print(col.upper())
    print(train_titanic[col].value_counts())
    print(train_titanic[col].hist())
    plt.show()
# Out:
# PASSENGER_ID
# 434    1
# 620    1
# 312    1
# 782    1
# 773    1
#       ..
# 539    1
# 563    1
# 194    1
# 813    1
# 579    1
# Name: passenger_id, Length: 534, dtype: int64
# Axes(0.125,0.11;0.775x0.77)
# AGE
# 30.00    17
# 18.00    17
# 22.00    16
# 35.00    16
# 24.00    15
# 19.00    15
# 28.00    15
# 21.00    14
# 25.00    14
# 36.00    13
# 29.00    12
# 16.00    11
# 32.00    11
# 38.00     9
# 39.00     9
# 34.00     9
# 31.00     9
# 20.00     9
# 27.00     8
# 40.00     8
# 17.00     8
# 44.00     7
# 42.00     7
# 54.00     7
# 50.00     7
# 23.00     7
# 33.00     7
# 26.00     7
# 1.00      6
# 2.00      6
# 37.00     5
# 41.00     5
# 58.00     5
# 45.00     5
# 48.00     5
# 4.00      5
# 47.00     4
# 52.00     4
# 14.00     4
# 51.00     4
# 9.00      4
# 49.00     3
# 62.00     3
# 8.00      3
# 43.00     3
# 5.00      3
# 30.50     2
# 3.00      2
# 61.00     2
# 0.75      2
# 6.00      2
# 7.00      2
# 28.50     2
# 13.00     2
# 60.00     2
# ...

# %% [markdown]
# b. Determine if certain columns should be dropped

# %% [markdown]
# No columns seem useless

# %% [markdown]
# c. Determine if it would be valuable to bin some numeric columns

# %% [markdown]
# sibsp and parch might need to be binned due to ooutliers

# %% [markdown]
# d. Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# No

# %% [markdown]
# e. Does it make sense to combine any features?

# %% [markdown]
# Class and fare may not be entirely independent

# %% [markdown]
# f. Do you find any surprises?

# %% [markdown]
# Not since we already did this in the lesson

# %% [markdown]
# Part 3 telco

# %%
telco_df = get_telco_data()
telco_df.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
telco_df = clean_telco(telco_df)
telco_df.T
# Out:
#                                               0               1     \
# customer_id                             0002-ORFBO      0003-MKNFE
# gender                                      Female            Male
# senior_citizen                                   0               0
# partner                                        Yes              No
# dependents                                     Yes              No
# tenure                                           9               9
# phone_service                                  Yes             Yes
# multiple_lines                                  No             Yes
# online_security                                 No              No
# online_backup                                  Yes              No
# device_protection                               No              No
# tech_support                                   Yes              No
# streaming_tv                                   Yes              No
# ...

# %%
train_telco, validate_telco, test_telco = split_data(telco_df, col_to_stratify='churn')
train_telco.shape
# Out:
# (4225, 45)

# %% [markdown]
# a. Explore your telco data to discover drivers of churn

# %%
# loop to separate categorical and numerical variables into lists

col_cat = [] #this is for my categorical varibles
col_num = [] #this is for my numeric varibles

for col in train_telco.columns[1:20]:
    print(col)
    if train_telco[col].dtype == 'O':
        col_cat.append(col)
    else:
        if len(train_telco[col].unique()) < 4: #making anything with less than 4 unique values a catergorical value
            col_cat.append(col)
        else:
            col_num.append(col)
# Out:
# gender
# senior_citizen
# partner
# dependents
# tenure
# phone_service
# multiple_lines
# online_security
# online_backup
# device_protection
# tech_support
# streaming_tv
# streaming_movies
# paperless_billing
# monthly_charges
# total_charges
# churn
# contract_type
# internet_service_type

# %%
col_num = ['tenure', 'monthly_charges', 'total_charges']

# %%
col_cat = ['gender',
 'senior_citizen',
 'partner',
 'dependents',
 'phone_service',
 'multiple_lines',
 'online_security',
 'online_backup',
 'device_protection',
 'tech_support',
 'streaming_tv',
 'streaming_movies',
 'paperless_billing',
 'churn',
 'contract_type',
 'internet_service_type']

# %%
# loop to get basic info on categorical variables
for col in col_cat:
    print(col.upper())
    print(train_telco[col].value_counts()) #modify this with new train data
    print(train_telco[col].value_counts(normalize=True)) #modify this with new train data
    sns.countplot(x=col, data=train_telco) #modify this with new train data
    plt.show()
    print()
# Out:
# GENDER
# Female    2131
# Male      2094
# Name: gender, dtype: int64
# Female    0.504379
# Male      0.495621
# Name: gender, dtype: float64
# SENIOR_CITIZEN
# 0    3551
# 1     674
# Name: senior_citizen, dtype: int64
# 0    0.840473
# 1    0.159527
# Name: senior_citizen, dtype: float64
# PARTNER
# No     2185
# Yes    2040
# Name: partner, dtype: int64
# No     0.51716
# Yes    0.48284
# Name: partner, dtype: float64
# DEPENDENTS
# No     2981
# Yes    1244
# Name: dependents, dtype: int64
# No     0.705562
# Yes    0.294438
# Name: dependents, dtype: float64
# PHONE_SERVICE
# Yes    3829
# No      396
# Name: phone_service, dtype: int64
# Yes    0.906272
# No     0.093728
# Name: phone_service, dtype: float64
# MULTIPLE_LINES
# No                  2042
# Yes                 1787
# No phone service     396
# Name: multiple_lines, dtype: int64
# No                  0.483314
# Yes                 0.422959
# No phone service    0.093728
# Name: multiple_lines, dtype: float64
# ...

# %% [markdown]
# b. Determine if certain columns should be dropped

# %% [markdown]
# Total charges might not be terribly useful

# %% [markdown]
# c. Determine if it would be valuable to bin some numeric columns

# %%
for col in col_num:
    print(col.upper())
    print(train_telco[col].value_counts())
    print(train_telco[col].hist())
    plt.show()
# Out:
# TENURE
# 1     370
# 72    220
# 2     152
# 3     132
# 4     100
# 71     97
# 7      78
# 12     75
# 5      75
# 70     74
# 10     74
# 9      71
# 8      69
# 13     64
# 15     64
# 68     61
# 18     59
# 22     58
# 69     58
# 6      57
# 11     54
# 66     54
# 24     53
# 56     51
# 67     49
# 29     49
# 30     48
# 17     48
# 20     48
# 19     48
# 60     47
# 35     47
# 27     47
# 63     47
# 53     46
# 50     46
# 14     46
# 25     46
# 23     46
# 62     45
# 16     45
# 51     45
# 46     45
# 65     45
# 54     44
# 52     44
# 61     44
# 41     43
# 64     43
# 49     43
# 33     43
# 26     42
# 43     42
# 57     41
# 32     40
# 45     40
# 47     40
# 37     38
# 58     38
# 59     37
# 42     37
# 21     36
# 39     36
# 34     35
# 38     35
# 40     34
# 48     34
# 55     33
# 36     33
# 31     32
# 28     31
# 44     30
# 0       4
# Name: tenure, dtype: int64
# Axes(0.125,0.11;0.775x0.77)
# MONTHLY_CHARGES
# 20.05    37
# 19.70    30
# ...

# %% [markdown]
# Tenure and monthly charges both have multiple peaks. They might be worth binning

# %% [markdown]
# d. Determine if it would be valuable to combine multiple columns into one.

# %%
train_telco.corr()
# Out:
# /var/folders/_6/0nkpzhxj2_n85fz5s1rk__xr0000gn/T/ipykernel_29789/3856784448.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_telco.corr()
#                                       senior_citizen    tenure  \
# senior_citizen                              1.000000  0.037281
# tenure                                      0.037281  1.000000
# monthly_charges                             0.211856  0.254306
# gender_Male                                 0.003815 -0.008178
# partner_Yes                                 0.030483  0.380287
# dependents_Yes                             -0.207694  0.153385
# phone_service_Yes                           0.011472  0.008180
# multiple_lines_No phone service            -0.011472 -0.008180
# multiple_lines_Yes                          0.159529  0.329722
# ...

# %%
sns.heatmap(data=train_telco.corr())
# Out:
# /var/folders/_6/0nkpzhxj2_n85fz5s1rk__xr0000gn/T/ipykernel_29789/2876545406.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=train_telco.corr())
# <Axes: >

# %% [markdown]
# phone service and multiple lines could likely be combined due to extremely high correlation

# %% [markdown]
# e. What are your drivers of churn?

# %%
a = .05
churn_stat = train_telco [train_telco.churn == 1].monthly_charges

no_churn_stat = train_telco [train_telco.churn == 0].monthly_charges
t, p = stats.mannwhitneyu(churn_stat, no_churn_stat)
t,p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[216], line 5
#       2 churn_stat = train_telco [train_telco.churn == 1].monthly_charges
#       4 no_churn_stat = train_telco [train_telco.churn == 0].monthly_charges
# ----> 5 t, p = stats.mannwhitneyu(churn_stat, no_churn_stat)
#       6 t,p
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:502, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     500 if sentinel:
#     501     samples = _remove_sentinel(samples, paired, sentinel)
# --> 502 res = hypotest_fun_out(*samples, **kwds)
#     503 res = result_to_tuple(res)
#     504 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# ...

# %%
monthly charges seems to be heavily related to churn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 train_telco_melt = train_telco.melt(id_vars=train_iris.churn,
#       2               value_vars=['tenure', 'monthly_charges', 'total_charges', 'gender',
#       3  'senior_citizen',
#       4  'partner',
#       5  'dependents',
#       6  'phone_service',
#       7  'multiple_lines',
#       8  'online_security',
#       9  'online_backup',
#      10  'device_protection',
#      11  'tech_support',
#      12  'streaming_tv',
#      13  'streaming_movies',
#      14  'paperless_billing',
#      15  'contract_type',
#      16  'internet_service_type'],
#      17               var_name = 'measure_type',
#      18               value_name='measure')
#      19 train_iris_melt.shape
#
# ...

# %% [markdown]
# f. Does it make sense to combine any features?

# %% [markdown]
# phone service and multiple lines seem nearly identical

# %% [markdown]
# g. Do you find any surprises?

# %% [markdown]
# monthly charges really bunch up at the bottom, requiring separate analysis of the more normally distributed data of higher values.
